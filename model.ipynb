# %% [markdown]
# # Powerset model
#
# ## Linear regression

# %%
# Load dataset
import statsmodels.api as sm
import pandas as pd
df = sm.datasets.get_rdataset("Guerry", "HistData").data
df = df[['Lottery', 'Literacy', 'Wealth', 'Region']].dropna()
df.head()
# Out:
#    Lottery  Literacy  Wealth Region
# 0       41        37      73      E
# 1       38        51      22      N
# 2       66        13      61      C
# 3       80        46      76      E
# 4       79        69      83      E

# %%
# Powerset
from scientistmetrics.model import powersetmodel

ols_res = powersetmodel(DTrain=df,target="Lottery")
ols_res[0]

# %%
ols_res[1]
# Out:
#                                 formula  expl. var. score  max error  \
# 0                    Lottery ~ Literacy          0.175695  38.503620
# 1                      Lottery ~ Wealth          0.288922  39.676641
# 2                      Lottery ~ Region          0.172453  40.500000
# 3           Lottery ~ Literacy + Wealth          0.338297  32.232160
# 4           Lottery ~ Literacy + Region          0.074931  46.334503
# 5             Lottery ~ Region + Wealth          0.415706  31.905235
# 6  Lottery ~ Region + Literacy + Wealth          0.357976  32.080593
#
#    mean abs. error  mean sq. error  mean sq. log error  median abs. error  \
# 0        17.749728      451.089398            0.601373          15.749965
# 1        17.105969      386.874758            0.479047          14.974282
# 2        17.784376      451.503485            0.596087          16.166667
# 3        16.810501      359.929569            0.460252          18.298454
# ...

# %% [markdown]
# ## Logistic regression

# %%
# load dataset
spector_data = sm.datasets.spector.load_pandas()
spector_data = pd.concat([spector_data.endog.to_frame(),spector_data.exog],axis=1)
spector_data.head()
# Out:
#    GRADE   GPA  TUCE  PSI
# 0    0.0  2.66  20.0  0.0
# 1    0.0  2.89  22.0  0.0
# 2    0.0  3.28  24.0  0.0
# 3    0.0  2.92  12.0  0.0
# 4    1.0  4.00  21.0  0.0

# %%
glm_res = powersetmodel(DTrain=spector_data,target="GRADE",model_type = "logistic")
glm_res[0]
